# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(100, 1700, 100)
n_3 = [-12.666262153123222,-8.851354927353258,-7.231156589466001,-6.419284614912161,-5.805065617844774\
      ,-5.544782357114798, -5.148838949405198, -4.876902172449064, -4.7268354309414855, -4.443147842903001\
      ,-4.305440087193065, -4.121413929947457, -3.914856618582642, -3.8184218170766493,\
      -3.7542705488213013, -3.5499467497593344]
n_4 = [-10.764196031112867, -6.78975550106081, - 5.251301067265561, -4.472633719702337, -4.105704523932153\
      ,-3.7620628206297653, -3.557717416231577, -3.3970168913711603, -3.2654764723849943, -3.105508994088915\
      ,-2.981694359631272, -2.8887757781994576, -2.7787347647472695, -2.7059347793272472, -2.5716282052671198,\
      -2.4918659815136643]
n_5 = [-9.131694693527441, -4.987894637911757, -3.7029061661040217, -3.071649776528384, -2.723350252588666,\
      -2.53944299456616, -2.3768367184461705, -2.2581603821725857, -2.123488818691983, -2.0820196200856835,\
      -1.987752525465293, -1.856283983412686, -1.8215872678339275, -1.7940857034912938, -1.698227688172692,\
      -1.6260843313054991]
n_6 = [-7.949267596756333, -3.8660882202140114, -2.633285544026506, -2.147979327748996, -1.8734362284434152,\
      -1.7326186527713812, -1.6380593945444988, -1.5466621390933293, -1.4814596482149458, -1.38755141714206,\
      -1.3476738315359877, -1.2581197459700018, -1.2232767613011728, -1.1849358872010263,\
      -1.1261683754566238, -1.087691775537748]

# plot lines
plt.figure(figsize=(15,10))
plt.plot(x, n_3, label = "max_depth = 3")
plt.plot(x, n_4, label = "max_depth = 4")
plt.plot(x, n_5, label = "max_depth = 5")
plt.plot(x, n_6, label = "max_depth = 6")
plt.xlabel('n_estimators')
plt.ylabel('negative mean squared error')
plt.xticks(x)

plt.legend()
plt.show()

# %%
# create data
x = np.arange(3,7)
m_100 = [-12.666262153123222, -10.764196031112867, -9.131694693527441, -7.949267596756333]
m_200 = [-8.851354927353258, -6.78975550106081, -4.987894637911757, -3.8660882202140114]
m_300 = [-7.231156589466001, -5.251301067265561, -3.7029061661040217, -2.633285544026506]
m_400 = [-6.419284614912161, -4.472633719702337, -3.071649776528384, -2.147979327748996]
m_500 = [-5.805065617844774, -4.105704523932153, -2.723350252588666, -1.8734362284434152]
m_600 = [-5.544782357114798, -3.7620628206297653, -2.53944299456616, -1.7326186527713812]
m_700 = [-5.148838949405198, -3.557717416231577, -2.3768367184461705, -1.6380593945444988]
m_800 = [-4.876902172449064, -3.3970168913711603, -2.2581603821725857, -1.5466621390933293]
m_900 = [-4.7268354309414855, -3.2654764723849943, -2.123488818691983, -1.4814596482149458]
m_1000 = [-4.443147842903001, -3.105508994088915, -2.0820196200856835, -1.38755141714206]
m_1100 = [-4.305440087193065, -2.981694359631272, -1.987752525465293, -1.3476738315359877]
m_1200 = [-4.121413929947457, -2.8887757781994576, -1.856283983412686, -1.2581197459700018]
m_1300 = [-3.914856618582642, -2.7787347647472695, -1.8215872678339275, -1.2232767613011728]
m_1400 = [-3.8184218170766493, -2.7059347793272472, -1.7940857034912938, -1.1849358872010263]
m_1500 = [-3.7542705488213013, -2.5716282052671198, -1.698227688172692, -1.1261683754566238]
m_1600 = [-3.5499467497593344, -2.4918659815136643, -1.6260843313054991, -1.087691775537748]


# plot lines
plt.figure(figsize=(15,10))
plt.plot(x, m_100, label = "n_estimators = 100")
plt.plot(x, m_200, label = "n_estimators = 200")
plt.plot(x, m_300, label = "n_estimators = 300")
plt.plot(x, m_400, label = "n_estimators = 400")
plt.plot(x, m_500, label = "n_estimators = 500")
plt.plot(x, m_600, label = "n_estimators = 600")
plt.plot(x, m_700, label = "n_estimators = 700")
plt.plot(x, m_800, label = "n_estimators = 800")
plt.plot(x, m_900, label = "n_estimators = 900")
plt.plot(x, m_1000, label = "n_estimators = 1000")
plt.plot(x, m_1100, label = "n_estimators = 1100")
plt.plot(x, m_1200, label = "n_estimators = 1200")
plt.plot(x, m_1300, label = "n_estimators = 1300")
plt.plot(x, m_1400, label = "n_estimators = 1400")
plt.plot(x, m_1500, label = "n_estimators = 1500")
plt.plot(x, m_1600, label = "n_estimators = 1600")
plt.xlabel('max_depth')
plt.ylabel('negative mean squared error')
plt.xticks(x)

plt.legend()
plt.show()
